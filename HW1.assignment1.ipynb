# %% [markdown]
# <a href="https://colab.research.google.com/github/ek182238/CSC349/blob/main/HW1.assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My first notebook**
#
# * This demonstrates how to create a simple notebook
# * etc.
#
# ![Screenshot 2026-08-29 121436.png](data:image/png;base64,...)

# %%
# !ls
# Out:
# sample_data

# %%
# !pwd
# Out:
# /content

# %%
x = 320
print(x)
# Out:
# 320
