# %% [markdown]
# <a href="https://colab.research.google.com/github/ek182238/CSC349/blob/main/HW3/HW3_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets, specifically regarding implicit data types like whitespace entries in TotalCharges?
#
# **One of the challenges I ran into with the whitespace in TotalCharges was that df.isna().sum() didn't consider them as missing values. I had to look through the data and use a different method than fillna() to fill in the whitespace entries.**
#
# 2. How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?
#
# **I determined which columns required missing value imputation after isna().sum() displayed 0 missing values for everything by going to the website on Kaggle, where it said in the TotalCharges column that there were missing values. I also noticed the data should have been numerical. I filled them in with 0 because whitespace most likely referred to no total charges.**
#
# 3. Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing and training steps.
#
# **ColumnTransformer makes it easier to work with a mix of data types without having to slice the DataFrame into separate DataFrames for categorical and numerical data. You simply use StandardScaler on numerical columns and OneHotEncoder on categorical columns. Both ColumnTransformer and Pipeline prevent data leakage by preventing extra steps involved with transforming the data.**
#
# 4. How did comparing StandardScaler versus MinMaxScaler impact your model training, convergence, or final evaluation metrics?
#
# **The MinMaxScaler affected the confusion matrices because there were a lot more false negatives in all the training sets.**
#
# 5. How does configuring SGDClassifier(loss='log_loss') differ from standard linear classification models, and what advantages do probability outputs and ROC-AUC metrics provide when evaluating customer churn?
#
# **Configuring SGDClassifier(loss='log_loss') differs from standard linear classification models because it is better for larger datasets, and it more heavily penalizes wrong predictions.**
#
# 6. Based on your model coefficients or feature evaluation, which features show the strongest relationship with customer churn, and what operational business insights do these findings reveal?
#
# **Based on the model coefficients and feature evaluation, Internet Service (fiber optic) showed the strongest relationship with customer churn. Contract (month-to-month) and Streaming TV (yes) also showed strong relationships with customer churn. This shows that customers with fiber optic internet or who stream TV are most likely to cancel their subscriptions, possibly due to pricing. It also shows that month-to-month contracts will not work very well for businesses who want customers to stay.**
