# %% [markdown]
# <a href="https://colab.research.google.com/github/ek182238/CSC349/blob/main/HW1/HW1_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
# **Run the code in Colab (or write code), then save a copy to GitHub. I saved it to the CSC349 repository and added “HW1/” to the file path to specify that it goes in the HW1 folder.**
#
# 2. Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
#
# **I was able to successfully execute all the Module 0 notebooks in Colab on the first try. Sometimes, I accidentally forgot to click "connect" in the beginning, so I had to wait a little longer for it to connect after running the first block of code. However, I didn't run into any problems.**
#
# 3. Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
# **I created the repository by following the first instructional video. I didn’t clone the repository in VS Code until after I uploaded all 5 notebooks to GitHub on the web, but I will be using VS code for it from this point on.**
#
# 4. Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
# **Establishing a strong command of basic Python data structures and syntax is critical before moving on to core ML algorithms because that will make it easier to understand the ML concepts without having to spend extra time figuring out how Python data structures work. Understanding libraries like pandas, numpy, and scikit-learn will also make data visualization and working with datasets easier.**
